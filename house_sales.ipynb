# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as ppt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
# reading the csv file and printing the data out
data = pd.read_csv('SalesData.csv')
print('data\n',data)
print('-'*80,'here we are printing the whole dataset')

# here we are checking the number of m issing data in the dataset
missing_data = np.size(np.isnan(data))
print('missing data = ',missing_data)

# here we are getting and printing the percentage of missing data
missing_data_per = (missing_data/data.count())
print('here we are printing out the percentage of missing data \n')
print(missing_data_per)
print('-'*60)

# plotting the heatmap
ppt.figure()
fig1 = sns.heatmap(data.isnull())
ppt.figure()
fig2 = sns.heatmap(data)

new_data =(data.dropna(axis=0,inplace=True))  #here we are dropping the null data

ppt.figure()
fig3 = sns.heatmap(data.isnull())
print(y)
X = data[['A', 'B', 'C']]
y = data['Sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42) #here we are assigning out data to test and train 

print('*'*70)
# print('Train data: \n')
# print(X_train,y_train)

# print('-'*80)

# print('Test Data: \n')
# print(X_test, y_test)

lin_model = LinearRegression()
lin_model.fit(X_train, y_train)

print('model: ', end='=> Y = ')
print(lin_model.coef_, 'X + ',lin_model.intercept_)
print('-'*80)
print('Model Evaluation')
print('MAE = ', end= '')
print(mean_absolute_error(y_test, predictions))

print('MSE =', end= '')
print(mean_squared_error(y_test,predictions))

print('EVS =', end= '')
print(explained_variance_score(y_test,predictions))
# predictions = lin_model.predict(X_test)
# print('\npredictions\n\n',predictions)
# Out:
# data
#            A          B    C        Sales
# 0     452.0   2.351549  450  3276.327890
# 1     247.0   3.163683   96  1112.946286
# 2     257.0  37.263322  340  2966.739801
# 3     416.0  19.804412  436  3451.479417
# 4     142.0  28.929087  180  1786.723571
# 5     170.0  32.218648  359  2795.935667
# 6     168.0  14.809340  404  2705.568120
# 7     328.0  10.535121  283  2341.632179
# 8     395.0  27.842064  124  1994.157159
# 9     467.0  46.126475  338  3537.276552
# 10    482.0  25.915817  334  3182.484707
# 11    374.0   6.709939  283  2366.778896
# 12    289.0  47.795175  302  3032.313144
# 13    125.0  45.905484  320  2757.298710
# 14    307.0  25.756749  158  1951.621477
# 15    327.0        NaN  309  3095.198038
# 16    316.0  16.868666  459  3312.635985
# 17    206.0  11.099257   49   939.786627
# 18    386.0  37.355119   60  1826.392140
# 19    200.0  30.157964  135  1699.843344
# 20    384.0  38.191912  276  2915.454418
# 21    320.0   5.411729  467  3152.411113
# ...
